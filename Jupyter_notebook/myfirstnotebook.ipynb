# %%
# Print a simple right-angled triangle star pattern
rows = 5
for i in range(1, rows + 1):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****

# %%
rows = 5
for i in range(1, rows + 1):
    print('*' * i)
# Out:
# *
# **
# ***
# ****
# *****
